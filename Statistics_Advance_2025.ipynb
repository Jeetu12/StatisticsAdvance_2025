# %% [markdown]
# ## 🧠 Advanced Statistics Interview Questions and Answers
#
# ### 🔹 **Topic 1: Random Variables**
#
# ---
#
# ### **1. What is a random variable in statistics, and how is it used in probability theory?**
#
# **Role**: Data Scientist, Data Analyst
# **Companies**: Google, Oracle
# **Difficulty**: ⭐⭐
#
# **Answer**:
# A **random variable** is a numerical outcome of a random phenomenon. In probability theory, it assigns a real number to each outcome in a sample space. Random variables allow us to **quantify uncertainty** and **model real-world phenomena**.
# There are two types:
#
# * **Discrete Random Variables**: take on a countable number of values (e.g., number of heads in 3 coin tosses).
# * **Continuous Random Variables**: take on an infinite number of values within a given range (e.g., height, weight).
#
# They form the foundation for defining **probability distributions**, calculating **expectations**, and conducting **inference**.
#
# ---
#
# ### **2. Explain the difference between discrete and continuous random variables.**
#
# **Role**: Data Scientist, Data Analyst
# **Companies**: Google, Oracle
# **Difficulty**: ⭐⭐
#
# **Answer**:
#
# | Feature     | Discrete Random Variable                      | Continuous Random Variable                       |
# | ----------- | --------------------------------------------- | ------------------------------------------------ |
# | Values      | Countable                                     | Infinite, uncountable                            |
# | Examples    | Number of students in class, dice roll        | Height, temperature                              |
# | Probability | Defined using PMF (Probability Mass Function) | Defined using PDF (Probability Density Function) |
# | Integration | Not required                                  | Area under the curve (PDF) used                  |
#
# **Key Point**: Discrete = individual values; Continuous = ranges of values.
#
# ---
#
# ### **3. How do you calculate the expected value of a random variable?**
#
# **Role**: Data Scientist, Data Analyst
# **Companies**: Google, Oracle
# **Difficulty**: ⭐⭐
#
# **Answer**:
# The **expected value (mean)** of a random variable gives the long-run average outcome of a random process.
#
# * For **Discrete Random Variable**:
#
#   $$
#   E[X] = \sum_{i} x_i \cdot P(x_i)
#   $$
#
# * For **Continuous Random Variable**:
#
#   $$
#   E[X] = \int_{-\infty}^{\infty} x \cdot f(x) \, dx
#   $$
#
# Where:
#
# * $x_i$: possible value
# * $P(x_i)$: probability of $x_i$
# * $f(x)$: probability density function
#
# ---
#
# ### **4. What role do random variables play in real-life data analysis problems?**
#
# **Role**: Data Scientist, Data Analyst
# **Companies**: Google, Oracle
# **Difficulty**: ⭐⭐
#
# **Answer**:
# Random variables help model **uncertain events** and are central to data analysis. For example:
#
# * In **fraud detection**, binary random variables can model fraud/no-fraud.
# * In **A/B testing**, the number of conversions is modeled as a binomial variable.
# * In **regression models**, outcomes are treated as random variables influenced by inputs.
#
# They allow analysts to calculate probabilities, expectations, variances, and guide decisions under uncertainty.
#
# ---
#
# Perfect! Let's move on to the next section: **Probability Distributions** — commonly asked in interviews for Data Science and Machine Learning roles at companies like Flipkart and Google.
#
# ---
#
# ## 🔹 **Topic 2: Probability Distributions**
#
# ---
#
# ### **5. What are probability distributions, and why are they important in statistics?**
#
# **Role**: Data Scientist, Machine Learning Engineer
# **Companies**: Flipkart, Google
# **Difficulty**: ⭐⭐⭐
#
# **Answer**:
# A **probability distribution** describes how the values of a **random variable** are distributed—it tells us the likelihood of different outcomes.
#
# There are two main types:
#
# * **Discrete Probability Distributions**: (e.g., Binomial, Poisson) for discrete variables.
# * **Continuous Probability Distributions**: (e.g., Normal, Exponential) for continuous variables.
#
# **Importance in statistics**:
#
# * Forms the foundation for **statistical inference**
# * Helps in **modeling uncertainty and variability** in data
# * Enables **hypothesis testing**, **confidence interval estimation**, and **predictive modeling**
#
# ---
#
# ### **6. Explain the difference between probability density function (PDF) and probability mass function (PMF).**
#
# **Role**: Data Analyst, Business Analyst
# **Companies**: Amazon, Zomato
# **Difficulty**: ⭐⭐
#
# **Answer**:
#
# | Feature        | PMF                                | PDF                                |
# | -------------- | ---------------------------------- | ---------------------------------- |
# | Used For       | Discrete random variables          | Continuous random variables        |
# | Definition     | $P(X = x)$ gives exact probability | $f(x)$ gives probability *density* |
# | Sum / Integral | $\sum P(x) = 1$                    | $\int f(x) dx = 1$                 |
# | Example        | Number of heads in coin toss       | Height of a person                 |
#
# > **Note**: For continuous distributions, the probability of a specific value is **zero**, so we talk about probability in intervals using PDF.
#
# ---
#
# ### **7. What is the cumulative density function (CDF), and how is it related to PDF and PMF?**
#
# **Role**: Data Science, Data Analytics
# **Companies**: Microsoft, Swiggy
# **Difficulty**: ⭐⭐⭐
#
# **Answer**:
# The **Cumulative Distribution Function (CDF)** gives the probability that a random variable is **less than or equal to a value** $x$:
#
# $$
# F(x) = P(X \leq x)
# $$
#
# * For **Discrete Variables**: $F(x) = \sum_{t \leq x} P(t)$
# * For **Continuous Variables**: $F(x) = \int_{-\infty}^{x} f(t) dt$
#
# **Relation**:
#
# * **PDF is the derivative of the CDF** for continuous variables:
#
#   $$
#   f(x) = \frac{dF(x)}{dx}
#   $$
#
# * **CDF is the summation of PMF** for discrete variables.
#
# ---
#
# ### **8. How do different types of probability distributions (discrete and continuous) differ?**
#
# **Role**: Data Science, Data Analytics
# **Companies**: Microsoft, Swiggy
# **Difficulty**: ⭐⭐⭐
#
# **Answer**:
#
# | Feature                | Discrete Distributions     | Continuous Distributions       |
# | ---------------------- | -------------------------- | ------------------------------ |
# | Examples               | Binomial, Poisson          | Normal, Exponential            |
# | Values                 | Countable (e.g., 0, 1, 2…) | Uncountable (any real value)   |
# | Representation         | PMF                        | PDF                            |
# | Probability at a Point | Non-zero                   | Always zero                    |
# | Area Concept           | Not required               | Area under curve = probability |
#
# **Use-case Difference**:
#
# * Discrete for things you **count** (emails received).
# * Continuous for things you **measure** (time, weight, temperature).
#
# ---
#
# Great! Let's now dive into **Topic 3: Types of Distributions**, focusing on interview-relevant differences and applications.
#
# ---
#
# ## 🔹 **Topic 3: Types of Distributions**
#
# ---
#
# ### **9. What are the main types of probability distributions in statistics?**
#
# **Role**: Data Scientist, Business Analyst
# **Companies**: Google, Paytm
# **Difficulty**: ⭐⭐
#
# **Answer**:
# The **main types of probability distributions** are categorized into:
#
# #### ✅ Discrete Distributions:
#
# * **Bernoulli Distribution**: Binary outcomes (0 or 1)
# * **Binomial Distribution**: Number of successes in *n* trials
# * **Poisson Distribution**: Number of events in a fixed interval
# * **Discrete Uniform**: All outcomes equally likely
#
# #### ✅ Continuous Distributions:
#
# * **Normal (Gaussian)**: Bell-shaped curve
# * **Uniform Distribution**: Equal probability across an interval
# * **Exponential Distribution**: Time until the next event
# * **Beta & Gamma Distributions**: Used in Bayesian stats, reliability
#
# Each has specific **use cases in modeling, prediction, and simulation**.
#
# ---
#
# ### **10. How do normal, binomial, and Poisson distributions differ?**
#
# **Role**: Data Analyst, Data Scientist
# **Companies**: Flipkart, Zomato
# **Difficulty**: ⭐⭐⭐
#
# | Feature    | Normal                  | Binomial                      | Poisson                                |
# | ---------- | ----------------------- | ----------------------------- | -------------------------------------- |
# | Type       | Continuous              | Discrete                      | Discrete                               |
# | Shape      | Bell Curve              | Symmetrical if p=0.5          | Skewed (can be symmetrical if λ large) |
# | Parameters | μ (mean), σ² (variance) | n (trials), p (success prob.) | λ (event rate)                         |
# | Use-case   | Heights, test scores    | Successes in trials           | Call arrivals per minute               |
#
# > 🔹 **Binomial → Poisson**: When n is large and p is small
# > 🔹 **Poisson → Normal**: When λ is large (central limit theorem applies)
#
# ---
#
# ### **11. When would you use a uniform distribution over a normal distribution?**
#
# **Role**: Data Scientist, Data Engineer
# **Companies**: Microsoft, Ola
# **Difficulty**: ⭐⭐
#
# **Answer**:
# Use a **uniform distribution** when:
#
# * **Every outcome in a range is equally likely**.
# * There's **no prior knowledge or bias** toward any outcome.
#
# 📌 Example: Simulating a **random number generator**, **card draw**, or **dice roll**.
#
# Use a **normal distribution** when:
#
# * The data is **symmetrically distributed**.
# * Most values cluster around the **mean** (e.g., heights, IQ scores).
#
# ---
#
# ### **12. Explain the concept of skewness in different probability distributions.**
#
# **Role**: Data Scientist, Data Engineer
# **Companies**: Microsoft, Ola
# **Difficulty**: ⭐⭐
#
# **Answer**:
# **Skewness** measures the **asymmetry** of a probability distribution.
#
# | Type                      | Description            | Example                 |
# | ------------------------- | ---------------------- | ----------------------- |
# | **Positive Skew (Right)** | Long tail to the right | Income distribution     |
# | **Negative Skew (Left)**  | Long tail to the left  | Test scores (easy exam) |
# | **Zero Skew**             | Symmetric              | Normal distribution     |
#
# * **Right-skewed**: Mean > Median > Mode
# * **Left-skewed**: Mean < Median < Mode
#
# > Skewness helps determine the **distribution type** and guide **data transformations**.
#
# ---
#
# ### **13. How is a probability density function (PDF) used in continuous probability distributions?**
#
# **Role**: Data Scientist, ML Engineer
# **Companies**: Flipkart, Google
# **Difficulty**: ⭐⭐⭐
#
# **Answer**:
# A **PDF** describes the **relative likelihood** of a continuous random variable taking on a specific value.
#
# Key points:
#
# * $P(a < X < b) = \int_{a}^{b} f(x)\,dx$
# * The **total area** under the PDF curve = 1
# * The value of the PDF at a point is **not a probability**, but **probability density**
#
# Example: Normal distribution
#
# $$
# f(x) = \frac{1}{\sqrt{2\pi\sigma^2}} \exp\left( -\frac{(x - \mu)^2}{2\sigma^2} \right)
# $$
#
# ---
#
# ### **14. Explain how the probability mass function (PMF) is used for discrete distributions.**
#
# **Role**: Data Analyst, Data Scientist
# **Companies**: Amazon, Swiggy
# **Difficulty**: ⭐⭐
#
# **Answer**:
# A **PMF** assigns probabilities to each **discrete outcome** of a random variable.
#
# $$
# P(X = x_i) = p_i
# \quad \text{where} \quad \sum_i p_i = 1
# $$
#
# Examples:
#
# * Tossing a coin: P(H) = 0.5, P(T) = 0.5
# * Rolling a die: P(1) = ... = P(6) = 1/6
#
# The PMF allows:
#
# * **Exact probability calculations**
# * Construction of **discrete distribution tables**
#
# ---
#
# ### **15. What is the relationship between PDF, PMF, and CDF?**
#
# **Role**: Data Scientist, Business Analyst
# **Companies**: Microsoft, Paytm
# **Difficulty**: ⭐⭐⭐
#
# **Answer**:
#
# | Function | Variable Type | Relation to CDF                     |
# | -------- | ------------- | ----------------------------------- |
# | PMF      | Discrete      | $F(x) = \sum_{t \le x} P(t)$        |
# | PDF      | Continuous    | $F(x) = \int_{-\infty}^{x} f(t) dt$ |
#
# **CDF** (Cumulative Distribution Function) is:
#
# * The **sum/integral** of probabilities/densities
# * **Non-decreasing**, ranges from 0 to 1
# * Useful in calculating **interval probabilities**
#
# ---
#
# Perfect! Let's move on to **Topic 4: Discrete Uniform Distribution**, which is frequently asked in interviews for roles involving basic probability modeling.
#
# ---
#
# ## 🔹 **Topic 4: Discrete Uniform Distribution**
#
# ---
#
# ### **16. What is a discrete uniform distribution, and when is it used?**
#
# **Role**: Data Scientist, Data Analyst
# **Companies**: Flipkart, TCS
# **Difficulty**: ⭐⭐
#
# **Answer**:
# A **Discrete Uniform Distribution** is a probability distribution where each **outcome in a finite set** is **equally likely**.
#
# #### Formula:
#
# If a random variable $X$ takes $n$ discrete values, each with equal probability:
#
# $$
# P(X = x_i) = \frac{1}{n}, \quad \text{for } i = 1, 2, ..., n
# $$
#
# #### Use cases:
#
# * Rolling a **fair die**
# * Picking a **random card** from a deck
# * **Random sampling** with replacement
#
# > 🔍 Used when there's **no bias or preference** among outcomes.
#
# ---
#
# ### **17. Give an example of a real-world problem where you can apply a discrete uniform distribution.**
#
# **Role**: Data Scientist, Data Analyst
# **Companies**: Flipkart, TCS
# **Difficulty**: ⭐⭐
#
# **Answer**:
# **Example**: Selecting a **random coupon code** from a list of 10 equally valuable options.
#
# Let $X$ be the selected coupon. Since each coupon has the same chance:
#
# $$
# P(X = x_i) = \frac{1}{10}
# $$
#
# Other examples:
#
# * Randomly assigning **tasks to team members**
# * Simulating a **coin toss** or **lottery draw**
#
# ---
#
# ### **18. How does a discrete uniform distribution differ from a continuous uniform distribution?**
#
# **Role**: Data Scientist, Data Analyst
# **Companies**: Flipkart, TCS
# **Difficulty**: ⭐⭐
#
# | Feature     | Discrete Uniform     | Continuous Uniform               |
# | ----------- | -------------------- | -------------------------------- |
# | Values      | Finite, countable    | Infinite, continuous interval    |
# | Example     | Dice roll            | Random number between 0 and 1    |
# | Probability | $P(x) = \frac{1}{n}$ | Density $f(x) = \frac{1}{b - a}$ |
# | Used in     | Sampling, games      | Simulation, modeling uncertainty |
#
# > 🔍 Discrete: Exact values
# > 🔍 Continuous: Ranges/intervals
#
# ---
#
# ### **19. Explain how to calculate the probability of an event in a discrete uniform distribution.**
#
# **Role**: Data Scientist, Data Analyst
# **Companies**: Flipkart, TCS
# **Difficulty**: ⭐⭐
#
# **Answer**:
# If a discrete uniform distribution has $n$ outcomes, then:
#
# $$
# P(X = x) = \frac{1}{n}
# $$
#
# For a subset $A \subseteq \{x_1, x_2, ..., x_n\}$,
#
# $$
# P(X \in A) = \frac{|A|}{n}
# $$
#
# **Example**: Probability of rolling an even number on a fair 6-sided die:
#
# $$
# P(X \in \{2, 4, 6\}) = \frac{3}{6} = 0.5
# $$
#
# ---
#
# ### **20. Numerical questions of the class can be asked.**
#
# **Role**: Data Scientist, Data Analyst
# **Companies**: Flipkart, TCS
# **Difficulty**: ⭐⭐
#
# **Example Interview Problem**:
#
# > A fair die is rolled once. What is the probability that the result is less than 5?
#
# **Solution**:
#
# * Possible outcomes: 1, 2, 3, 4, 5, 6
# * Desired outcomes: 1, 2, 3, 4 → 4 outcomes
#
# $$
# P(X < 5) = \frac{4}{6} = \frac{2}{3}
# $$
#
# ---
#
# Perfect! Let's move on to **Topic 4: Discrete Uniform Distribution**, which is frequently asked in interviews for roles involving basic probability modeling.
#
# ---
#
# ## 🔹 **Topic 4: Discrete Uniform Distribution**
#
# ---
#
# ### **16. What is a discrete uniform distribution, and when is it used?**
#
# **Role**: Data Scientist, Data Analyst
# **Companies**: Flipkart, TCS
# **Difficulty**: ⭐⭐
#
# **Answer**:
# A **Discrete Uniform Distribution** is a probability distribution where each **outcome in a finite set** is **equally likely**.
#
# #### Formula:
#
# If a random variable $X$ takes $n$ discrete values, each with equal probability:
#
# $$
# P(X = x_i) = \frac{1}{n}, \quad \text{for } i = 1, 2, ..., n
# $$
#
# #### Use cases:
#
# * Rolling a **fair die**
# * Picking a **random card** from a deck
# * **Random sampling** with replacement
#
# > 🔍 Used when there's **no bias or preference** among outcomes.
#
# ---
#
# ### **17. Give an example of a real-world problem where you can apply a discrete uniform distribution.**
#
# **Role**: Data Scientist, Data Analyst
# **Companies**: Flipkart, TCS
# **Difficulty**: ⭐⭐
#
# **Answer**:
# **Example**: Selecting a **random coupon code** from a list of 10 equally valuable options.
#
# Let $X$ be the selected coupon. Since each coupon has the same chance:
#
# $$
# P(X = x_i) = \frac{1}{10}
# $$
#
# Other examples:
#
# * Randomly assigning **tasks to team members**
# * Simulating a **coin toss** or **lottery draw**
#
# ---
#
# ### **18. How does a discrete uniform distribution differ from a continuous uniform distribution?**
#
# **Role**: Data Scientist, Data Analyst
# **Companies**: Flipkart, TCS
# **Difficulty**: ⭐⭐
#
# | Feature     | Discrete Uniform     | Continuous Uniform               |
# | ----------- | -------------------- | -------------------------------- |
# | Values      | Finite, countable    | Infinite, continuous interval    |
# | Example     | Dice roll            | Random number between 0 and 1    |
# | Probability | $P(x) = \frac{1}{n}$ | Density $f(x) = \frac{1}{b - a}$ |
# | Used in     | Sampling, games      | Simulation, modeling uncertainty |
#
# > 🔍 Discrete: Exact values
# > 🔍 Continuous: Ranges/intervals
#
# ---
#
# ### **19. Explain how to calculate the probability of an event in a discrete uniform distribution.**
#
# **Role**: Data Scientist, Data Analyst
# **Companies**: Flipkart, TCS
# **Difficulty**: ⭐⭐
#
# **Answer**:
# If a discrete uniform distribution has $n$ outcomes, then:
#
# $$
# P(X = x) = \frac{1}{n}
# $$
#
# For a subset $A \subseteq \{x_1, x_2, ..., x_n\}$,
#
# $$
# P(X \in A) = \frac{|A|}{n}
# $$
#
# **Example**: Probability of rolling an even number on a fair 6-sided die:
#
# $$
# P(X \in \{2, 4, 6\}) = \frac{3}{6} = 0.5
# $$
#
# ---
#
# ### **20. Numerical questions of the class can be asked.**
#
# **Role**: Data Scientist, Data Analyst
# **Companies**: Flipkart, TCS
# **Difficulty**: ⭐⭐
#
# **Example Interview Problem**:
#
# > A fair die is rolled once. What is the probability that the result is less than 5?
#
# **Solution**:
#
# * Possible outcomes: 1, 2, 3, 4, 5, 6
# * Desired outcomes: 1, 2, 3, 4 → 4 outcomes
#
# $$
# P(X < 5) = \frac{4}{6} = \frac{2}{3}
# $$
#
# ---
#
# Great! Let's move on to **Topic 5: Bernoulli and Binomial Distribution**, which are fundamental to classification problems and probabilistic modeling in Data Science and Machine Learning.
#
# ---
#
# ## 🔹 **Topic 5: Bernoulli and Binomial Distribution**
#
# ---
#
# ### **21. What is the Bernoulli distribution, and what are its properties?**
#
# **Role**: Data Scientist, Data Analyst
# **Companies**: Flipkart, Ola
# **Difficulty**: ⭐⭐
#
# **Answer**:
# A **Bernoulli distribution** models a **single trial** that results in either **success (1)** or **failure (0)**, with probability $p$ of success.
#
# #### Properties:
#
# * Only **two outcomes**: 1 (success), 0 (failure)
# * Mean: $\mu = p$
# * Variance: $\sigma^2 = p(1 - p)$
# * PMF:
#
#   $$
#   P(X = x) = p^x (1 - p)^{1 - x}, \quad x \in \{0, 1\}
#   $$
#
# > 🔍 Used in binary events like pass/fail, win/lose, click/no-click.
#
# ---
#
# ### **22. Explain how a Bernoulli trial is used in binary classification problems.**
#
# **Role**: ML Engineer, Data Scientist
# **Companies**: Google, Swiggy
# **Difficulty**: ⭐⭐⭐
#
# **Answer**:
# A **Bernoulli trial** simulates **yes/no** outcomes in binary classification, such as:
#
# * Spam or not spam
# * Disease present or not
#
# In a **binary classifier** (like logistic regression), the predicted probability $p$ of the positive class can be modeled using a Bernoulli distribution:
#
# $$
# P(Y = 1) = p, \quad P(Y = 0) = 1 - p
# $$
#
# This forms the basis of **loss functions** like binary cross-entropy.
#
# ---
#
# ### **23. How does the Bernoulli distribution relate to the binomial distribution?**
#
# **Role**: Data Scientist, Data Analyst
# **Companies**: Flipkart, Ola
# **Difficulty**: ⭐⭐
#
# **Answer**:
# The **Binomial distribution** is the **sum of independent Bernoulli trials**.
#
# If $X_1, X_2, ..., X_n \sim \text{Bernoulli}(p)$, then:
#
# $$
# S = X_1 + X_2 + \dots + X_n \sim \text{Binomial}(n, p)
# $$
#
# * Bernoulli: One trial
# * Binomial: $n$ trials
#
# > 🔁 Binomial = Repeated Bernoulli
#
# ---
#
# ### **24. When would you use a Bernoulli distribution in data science?**
#
# **Role**: Data Scientist, Data Analyst
# **Companies**: Flipkart, Ola
# **Difficulty**: ⭐⭐
#
# **Answer**:
# Use Bernoulli distribution when modeling:
#
# * Binary outcomes (e.g., **customer churn**, **fraud detection**)
# * Feature selection (e.g., **Bernoulli Naive Bayes**)
# * Simulation of single binary experiments
#
# > 🧪 When a process has only **2 outcomes** (yes/no), use Bernoulli.
#
# ---
#
# ### **25. What is the binomial distribution, and how does it differ from the Bernoulli distribution?**
#
# **Role**: Data Scientist, Business Analyst
# **Companies**: Amazon, Flipkart
# **Difficulty**: ⭐⭐⭐
#
# **Answer**:
# A **Binomial distribution** models the **number of successes in $n$ independent Bernoulli trials**, each with probability $p$.
#
# #### PMF:
#
# $$
# P(X = k) = \binom{n}{k} p^k (1 - p)^{n - k}
# $$
#
# **Differences**:
#
# | Feature  | Bernoulli  | Binomial    |
# | -------- | ---------- | ----------- |
# | Trials   | 1          | $n$         |
# | Values   | 0 or 1     | 0 to $n$    |
# | Mean     | $p$        | $np$        |
# | Variance | $p(1 - p)$ | $np(1 - p)$ |
#
# ---
#
# ### **26. Explain how to calculate the probability of multiple events in a binomial distribution.**
#
# **Role**: Data Analyst, Data Scientist
# **Companies**: Google, Zomato
# **Difficulty**: ⭐⭐
#
# **Answer**:
# To calculate $P(X = k)$ for $k$ successes in $n$ trials:
#
# $$
# P(X = k) = \binom{n}{k} p^k (1 - p)^{n - k}
# $$
#
# **Example**: Flip a coin 5 times, probability of 3 heads:
#
# $$
# P(X = 3) = \binom{5}{3} (0.5)^3 (0.5)^2 = 10 \times 0.125 \times 0.25 = 0.3125
# $$
#
# ---
#
# ### **27. What is the binomial coefficient, and why is it important in the binomial distribution?**
#
# **Role**: Data Scientist, Data Analyst
# **Companies**: Flipkart, Ola
# **Difficulty**: ⭐⭐
#
# **Answer**:
# The **binomial coefficient** $\binom{n}{k}$ represents the **number of ways** to choose $k$ successes from $n$ trials.
#
# $$
# \binom{n}{k} = \frac{n!}{k!(n - k)!}
# $$
#
# It accounts for the **combinatorics** of different success arrangements in the binomial PMF.
#
# ---
#
# ### **28. How would you implement a binomial distribution in Python using NumPy?**
#
# **Role**: Data Scientist, Data Analyst
# **Companies**: Flipkart, Ola
# **Difficulty**: ⭐⭐
#
# ```python
# import numpy as np
#
# # Parameters
# n = 10  # trials
# p = 0.3  # probability of success
#
# # Generate 1000 samples
# samples = np.random.binomial(n=n, p=p, size=1000)
#
# # Basic stats
# print("Mean:", np.mean(samples))
# print("Std Dev:", np.std(samples))
# ```
#
# > 🧪 You can also use `scipy.stats.binom.pmf(k, n, p)` for exact probabilities.
#
# ---

# %%
import numpy as np

# Parameters
n = 10  # trials
p = 0.3  # probability of success

# Generate 1000 samples
samples = np.random.binomial(n=n, p=p, size=1000)

# Basic stats
print("Mean:", np.mean(samples))
print("Std Dev:", np.std(samples))
# Out:
# Mean: 3.088
# Std Dev: 1.4499158596277233

# %% [markdown]
# Great! Let's move on to **🔹Topic 7: Continuous Uniform Distribution**, which is one of the simplest continuous probability distributions.
#
# ---
#
# ## 🔹 **Topic 7: Continuous Uniform Distribution**
#
# ---
#
# ### **33. What is the continuous uniform distribution, and when is it applicable?**
#
# **Role**: Data Scientist, Data Analyst
# **Companies**: Google, Flipkart
# **Difficulty**: ⭐⭐
#
# **Answer**:
# A **continuous uniform distribution** is where all outcomes in a continuous range $[a, b]$ are **equally likely**.
# It is used when there is **no preference or bias** over the range.
#
# #### Probability Density Function (PDF):
#
# $$
# f(x) = \frac{1}{b - a} \quad \text{for } a \leq x \leq b
# $$
#
# **Use Cases**:
#
# * Generating random numbers
# * Modeling equally probable outcomes (e.g., random delays, timer settings)
#
# ---
#
# ### **34. Explain how to calculate the probability of an event in a continuous uniform distribution.**
#
# **Role**: Data Scientist, Business Analyst
# **Companies**: Microsoft, Ola
# **Difficulty**: ⭐⭐⭐
#
# **Answer**:
# For a continuous uniform distribution between $a$ and $b$, the probability that $X$ lies between $x_1$ and $x_2$ is:
#
# $$
# P(x_1 \leq X \leq x_2) = \frac{x_2 - x_1}{b - a}
# $$
#
# ✅ **Example**: If $X \sim U(10, 20)$, find $P(12 \leq X \leq 15)$:
#
# $$
# P = \frac{15 - 12}{20 - 10} = \frac{3}{10} = 0.3
# $$
#
# ---
#
# ### **35. How does a continuous uniform distribution differ from a normal distribution?**
#
# **Role**: Data Science, Data Analytics
# **Companies**: Amazon, Swiggy
# **Difficulty**: ⭐⭐
#
# | Feature      | Continuous Uniform Distribution | Normal Distribution                         |
# | ------------ | ------------------------------- | ------------------------------------------- |
# | Shape        | Rectangular (flat)              | Bell-shaped (Gaussian)                      |
# | PDF          | Constant over $[a, b]$          | Changes with $x$; peak at mean              |
# | Parameters   | $a$, $b$                        | $\mu$, $\sigma$                             |
# | Mean         | $\frac{a + b}{2}$               | $\mu$                                       |
# | Applications | Random number generation        | Natural data modeling (height, weight, etc) |
#
# ---
#
# ### **36. Provide a Python implementation of a continuous uniform distribution using NumPy.**
#
# **Role**: Data Scientist, Data Analyst
# **Companies**: Amazon, Swiggy
# **Difficulty**: ⭐⭐
#
# ```python
# import numpy as np
# import matplotlib.pyplot as plt
#
# # Generate 1000 samples from U(0, 10)
# samples = np.random.uniform(0, 10, 1000)
#
# # Plot histogram
# plt.hist(samples, bins=20, edgecolor='black', density=True)
# plt.title("Continuous Uniform Distribution U(0, 10)")
# plt.xlabel("Value")
# plt.ylabel("Probability")
# plt.show()
# ```
#
# ---

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate 1000 samples from U(0, 10)
samples = np.random.uniform(0, 10, 1000)

# Plot histogram
plt.hist(samples, bins=20, edgecolor='black', density=True)
plt.title("Continuous Uniform Distribution U(0, 10)")
plt.xlabel("Value")
plt.ylabel("Probability")
plt.show()

# %% [markdown]
# Excellent! Let’s now cover **🔹Topic 8: Normal Distribution**, which is the foundation for much of statistical analysis and machine learning.
#
# ---
#
# ## 🔹 **Topic 8: Normal Distribution**
#
# ---
#
# ### **37. What is the normal distribution, and why is it important in statistics?**
#
# **Role**: Data Scientist, Business Analyst
# **Companies**: Google, Flipkart
# **Difficulty**: ⭐⭐⭐
#
# **Answer**:
# The **normal distribution** (or Gaussian distribution) is a **bell-shaped**, symmetric probability distribution characterized by:
#
# * **Mean** ($\mu$): the center of the distribution
# * **Standard deviation** ($\sigma$): spread or width of the curve
#
# It is important because:
#
# * Many **natural phenomena** follow it (e.g., height, IQ)
# * It supports **inferential statistics** (CLT, hypothesis testing)
# * Many models assume **normality** in residuals/errors
#
# ---
#
# ### **38. Explain the properties of the normal distribution curve.**
#
# **Role**: Data Scientist, Data Analyst
# **Companies**: Microsoft, Swiggy
# **Difficulty**: ⭐⭐
#
# **Properties**:
#
# * Symmetric about the mean ($\mu$)
# * Mean = Median = Mode
# * Total area under the curve = 1
# * Empirical Rule (68-95-99.7 Rule):
#
#   * \~68% of data within 1σ
#   * \~95% within 2σ
#   * \~99.7% within 3σ
#
# $$
# f(x) = \frac{1}{\sqrt{2\pi\sigma^2}} e^{ -\frac{(x - \mu)^2}{2\sigma^2} }
# $$
#
# ---
#
# ### **39. When would you use a normal distribution over other probability distributions?**
#
# **Role**: Data Science, Data Analyst
# **Companies**: Microsoft, Swiggy
# **Difficulty**: ⭐⭐
#
# **Use a normal distribution when**:
#
# * The dataset is **symmetric** and **bell-shaped**
# * You are working with **large samples** (due to the Central Limit Theorem)
# * You need to apply **parametric tests** (Z-test, T-test)
# * Data is **continuous** and influenced by many small, independent effects
#
# ---
#
# ### **40. How would you generate a normal distribution in Python using SciPy?**
#
# **Role**: Data Scientist, Data Analyst
# **Companies**: Microsoft, Swiggy
# **Difficulty**: ⭐⭐
#
# ```python
# from scipy.stats import norm
# import numpy as np
# import matplotlib.pyplot as plt
#
# # Parameters
# mu, sigma = 0, 1
#
# # Generate data
# x = np.linspace(-4, 4, 1000)
# y = norm.pdf(x, mu, sigma)
#
# # Plot
# plt.plot(x, y)
# plt.title('Standard Normal Distribution')
# plt.xlabel('x')
# plt.ylabel('Probability Density')
# plt.grid(True)
# plt.show()
# ```
#
# ---

# %%
from scipy.stats import norm
import numpy as np
import matplotlib.pyplot as plt

# Parameters
mu, sigma = 0, 1

# Generate data
x = np.linspace(-4, 4, 1000)
y = norm.pdf(x, mu, sigma)

# Plot
plt.plot(x, y)
plt.title('Standard Normal Distribution')
plt.xlabel('x')
plt.ylabel('Probability Density')
plt.grid(True)
plt.show()

# %% [markdown]
# Great! Let's move to **🔹Topic 9: Standard Normal Distribution**, a core part of understanding z-scores and standardized values.
#
# ---
#
# ## 🔹**Topic 9: Standard Normal Distribution**
#
# ---
#
# ### **41. What is the standard normal distribution, and how is it related to the normal distribution?**
#
# **Role**: Data Science, Data Analyst
# **Companies**: Flipkart, Paytm
# **Difficulty**: ⭐⭐
#
# **Answer**:
# The **standard normal distribution** is a special case of the normal distribution where:
#
# * Mean ($\mu$) = 0
# * Standard deviation ($\sigma$) = 1
#
# **Relation**:
# Any normal distribution $N(\mu, \sigma)$ can be transformed to the standard normal distribution using a **z-score**:
#
# $$
# Z = \frac{X - \mu}{\sigma}
# $$
#
# This transformation allows comparison between different normal distributions and is essential in **hypothesis testing** and **confidence intervals**.
#
# ---
#
# ### **42. How do you convert a normal distribution to a standard normal distribution?**
#
# **Role**: Business Analyst, Data Scientist
# **Companies**: Microsoft, Zomato
# **Difficulty**: ⭐⭐⭐
#
# **Conversion Process**:
# Use the **z-score formula**:
#
# $$
# Z = \frac{X - \mu}{\sigma}
# $$
#
# Where:
#
# * $X$: observed value
# * $\mu$: mean of the distribution
# * $\sigma$: standard deviation
#
# This process is called **standardization**, and it helps in:
#
# * Calculating probabilities using standard normal tables
# * Comparing scores across different distributions
#
# ---
#
# ### **43. Explain the significance of the z-score in a standard normal distribution.**
#
# **Role**: Data Science, Data Engineer
# **Companies**: Google, Flipkart
# **Difficulty**: ⭐⭐
#
# **Answer**:
# A **z-score** tells us how many standard deviations an observation is from the mean.
#
# * **Positive z-score**: value above the mean
# * **Negative z-score**: value below the mean
# * **Z = 0**: value is at the mean
#
# Z-scores help in:
#
# * Outlier detection
# * Normalizing data
# * Hypothesis testing (e.g., calculating p-values)
#
# ---
#
# ### **44. How do you calculate the z-score in Python for a given dataset?**
#
# **Role**: Data Science, Data Engineer
# **Companies**: Google, Flipkart
# **Difficulty**: ⭐⭐
#
# ```python
# import numpy as np
# from scipy.stats import zscore
#
# # Example dataset
# data = np.array([90, 80, 75, 92, 85, 88])
#
# # Calculate z-scores
# z_scores = zscore(data)
# print(z_scores)
# ```
#
# Output:
#
# ```
# [ 1.069  -0.267  -1.069  1.472   0.267   0.627]  # Approximate values
# ```
#
# ---

# %%
import numpy as np
from scipy.stats import zscore

# Example dataset
data = np.array([90, 80, 75, 92, 85, 88])

# Calculate z-scores
z_scores = zscore(data)
print(z_scores)
# Out:
# [ 0.84920778 -0.84920778 -1.69841555  1.18889089  0.          0.50952467]

# %% [markdown]
# Awesome! Let’s now move to **🔹Topic 10: Central Limit Theorem (CLT)**—one of the most important principles in statistics for Data Science and Machine Learning.
#
# ---
#
# ## 🔹**Topic 10: Central Limit Theorem (CLT)**
#
# ---
#
# ### **45. What is the central limit theorem, and why is it important in statistics?**
#
# **Role**: Data Science, Data Analyst, Machine Learning Engineer
# **Companies**: Microsoft, Zomato
# **Difficulty**: ⭐⭐⭐
#
# **Answer**:
# The **Central Limit Theorem (CLT)** states that the **sampling distribution** of the **sample mean** approaches a **normal distribution** as the **sample size becomes large**, regardless of the original population distribution.
#
# Mathematically:
# If $X_1, X_2, ..., X_n$ are i.i.d. with mean $\mu$ and standard deviation $\sigma$, then:
#
# $$
# \bar{X} = \frac{1}{n} \sum_{i=1}^{n} X_i \approx N\left(\mu, \frac{\sigma}{\sqrt{n}}\right)
# $$
#
# **Importance**:
#
# * Enables the use of **normal approximation** for many statistical methods
# * Forms the foundation of **hypothesis testing**, **confidence intervals**, and **z-tests**
#
# ---
#
# ### **46. How does the central limit theorem apply to large sample sizes?**
#
# **Role**: Data Science, Data Analyst, Machine Learning Engineer
# **Companies**: Microsoft, Zomato
# **Difficulty**: ⭐⭐⭐
#
# **Answer**:
# As the sample size **$n$** increases:
#
# * The distribution of the **sample mean** becomes increasingly **normal**.
# * The **standard error** decreases:
#
#   $$
#   \text{Standard Error} = \frac{\sigma}{\sqrt{n}}
#   $$
#
# **Rule of Thumb**:
# Sample size $n \geq 30$ is generally sufficient for the CLT to hold, even if the population is skewed.
#
# ---
#
# ### **47. Explain the role of the central limit theorem in hypothesis testing.**
#
# **Role**: Data Science, Data Analyst, Machine Learning Engineer
# **Companies**: Microsoft, Zomato
# **Difficulty**: ⭐⭐⭐
#
# **Answer**:
# CLT justifies the use of **z-tests** and **t-tests** by ensuring that the distribution of sample means is approximately **normal** for large $n$.
#
# **In hypothesis testing**:
#
# * The null hypothesis assumes a population mean
# * We test the sample mean using the normal approximation from CLT
# * Enables calculation of p-values and critical regions
#
# ---
#
# ### **48. Provide an example of how the central limit theorem is used in real-world data analysis.**
#
# **Role**: Data Science, Data Analyst, Machine Learning Engineer
# **Companies**: Microsoft, Zomato
# **Difficulty**: ⭐⭐⭐
#
# **Example**:
# A food delivery company wants to analyze the **average delivery time**.
#
# * The individual delivery times may be skewed (e.g., due to traffic).
# * However, by taking samples of delivery times (e.g., 50 orders each), the **mean delivery time per sample** will follow a **normal distribution**.
# * This allows analysts to perform **confidence interval estimation** or **hypothesis testing** on average delivery time.
#
# ---
#
# Great! Let’s dive into **🔹Topic 11: Estimate and p-value**—crucial for making inferences from data in interviews and real-world data analysis.
#
# ---
#
# ## 🔹**Topic 11: Estimate and p-value**
#
# ---
#
# ### **49. What is an estimate in statistics, and how does it differ from a parameter?**
#
# **Role**: Data Science, Data Analyst
# **Companies**: Amazon, Flipkart
# **Difficulty**: ⭐⭐
#
# **Answer**:
#
# * A **parameter** is a **fixed, unknown value** that describes a population (e.g., population mean $\mu$).
# * An **estimate** is a **calculated approximation** of that parameter using sample data (e.g., sample mean $\bar{x}$).
#
# 🔹 *Example*: If we can't survey all customers to find the true average spending, we estimate it using a sample of customers.
#
# ---
#
# ### **50. Explain the difference between a point estimate and an interval estimate.**
#
# **Role**: Data Science, Data Analyst
# **Companies**: Amazon, Flipkart
# **Difficulty**: ⭐⭐
#
# **Answer**:
#
# * **Point Estimate**: A single value used to estimate a population parameter (e.g., $\bar{x} = 50$).
# * **Interval Estimate**: A range within which the parameter likely falls, usually expressed as a **confidence interval** (e.g., $47 \leq \mu \leq 53$ with 95% confidence).
#
# ---
#
# ### **51. Why is estimation important in inferential statistics?**
#
# **Role**: Data Science, Data Analyst
# **Companies**: Amazon, Flipkart
# **Difficulty**: ⭐⭐
#
# **Answer**:
# Estimation allows analysts to:
#
# * Make predictions or decisions about a population using sample data.
# * Quantify **uncertainty** in decision-making.
# * Avoid needing a **complete census** of the data.
#
# ---
#
# ### **52. How do you calculate confidence intervals for an estimate in Python?**
#
# **Role**: Data Science, Data Analyst
# **Companies**: Amazon, Flipkart
# **Difficulty**: ⭐⭐
#
# **Answer**:
#
# ```python
# import numpy as np
# import scipy.stats as stats
#
# # Sample data
# data = [22, 25, 20, 30, 27, 24, 26]
# mean = np.mean(data)
# sem = stats.sem(data)  # Standard error of the mean
# conf_int = stats.t.interval(0.95, df=len(data)-1, loc=mean, scale=sem)
#
# print("95% Confidence Interval:", conf_int)
# ```
#
# ---
#
# ### **53. What is a p-value, and how is it used in hypothesis testing?**
#
# **Role**: Data Science, Business Analyst
# **Companies**: Flipkart, Google
# **Difficulty**: ⭐⭐⭐
#
# **Answer**:
# A **p-value** is the **probability** of obtaining test results at least as extreme as the observed results, assuming the null hypothesis is true.
#
# 🔹 **Interpretation**:
#
# * **Small p-value** (< α): Strong evidence against the null → reject it
# * **Large p-value**: Insufficient evidence → fail to reject the null
#
# ---
#
# ### **54. Explain the significance of a low p-value in statistical analysis.**
#
# **Role**: Data Analyst, Data Scientist
# **Companies**: Amazon, Zomato
# **Difficulty**: ⭐⭐
#
# **Answer**:
# A **low p-value** (typically < 0.05) suggests that:
#
# * The observed effect is **unlikely** due to random chance.
# * There is **statistical significance** in the result.
# * The null hypothesis should be **rejected**.
#
# ---
#
# ### **55. When would you reject the null hypothesis based on the p-value?**
#
# **Role**: Data Science, Data Engineer
# **Companies**: Microsoft, Swiggy
# **Difficulty**: ⭐⭐
#
# **Answer**:
# If the **p-value < α** (e.g., 0.05), we reject the **null hypothesis** because the result is statistically significant.
#
# ---
#
# ### **56. How would you calculate the p-value in Python using scipy.stats?**
#
# **Role**: Data Science, Data Engineer
# **Companies**: Microsoft, Swiggy
# **Difficulty**: ⭐⭐
#
# **Answer**:
#
# ```python
# from scipy import stats
#
# # One-sample t-test
# sample = [5, 6, 7, 8, 9]
# t_stat, p_value = stats.ttest_1samp(sample, popmean=6)
#
# print("T-statistic:", t_stat)
# print("P-value:", p_value)
# ```
#
# ---

# %%
from scipy import stats

# One-sample t-test
sample = [5, 6, 7, 8, 9]
t_stat, p_value = stats.ttest_1samp(sample, popmean=6)

print("T-statistic:", t_stat)
print("P-value:", p_value)
# Out:
# T-statistic: 1.414213562373095
# P-value: 0.23019964108049873

# %%
import numpy as np
import scipy.stats as stats

# Sample data
data = [22, 25, 20, 30, 27, 24, 26]
mean = np.mean(data)
sem = stats.sem(data)  # Standard error of the mean
conf_int = stats.t.interval(0.95, df=len(data)-1, loc=mean, scale=sem)

print("95% Confidence Interval:", conf_int)
# Out:
# 95% Confidence Interval: (np.float64(21.81644977819723), np.float64(27.897835936088484))

# %% [markdown]
# Great! Let’s move on to **🔹Topic 12: Z-Statistics**, a core concept in inferential statistics used frequently in hypothesis testing and confidence interval calculations.
#
# ---
#
# ## 🔹**Topic 12: Z-Statistics**
#
# ---
#
# ### **57. What is a Z-statistic, and when is it used in hypothesis testing?**
#
# **Role**: Data Science, Data Analyst
# **Companies**: Amazon, Flipkart
# **Difficulty**: ⭐⭐⭐
#
# **Answer**:
# A **Z-statistic** (or Z-score) measures how many standard deviations an observation is from the mean.
#
# **Formula**:
#
# $$
# Z = \frac{\bar{x} - \mu}{\sigma / \sqrt{n}}
# $$
#
# Where:
#
# * $\bar{x}$ = sample mean
# * $\mu$ = population mean
# * $\sigma$ = population standard deviation
# * $n$ = sample size
#
# ✅ **Used When**:
#
# * Population standard deviation ($\sigma$) is **known**
# * Sample size is **large** (typically $n \geq 30$)
#
# ---
#
# ### **58. How does the Z-stat differ from the T-stat?**
#
# **Role**: Data Science, Data Analyst
# **Companies**: Amazon, Flipkart
# **Difficulty**: ⭐⭐⭐
#
# | Feature      | Z-Statistic                         | T-Statistic                    |
# | ------------ | ----------------------------------- | ------------------------------ |
# | Use Case     | Known population std dev ($\sigma$) | Unknown population std dev     |
# | Sample Size  | Typically $n \geq 30$               | Typically $n < 30$             |
# | Distribution | Standard normal (N(0,1))            | Student’s t-distribution       |
# | Shape        | Fixed                               | Varies with degrees of freedom |
#
# ---
#
# ### **59. Explain how to compute a Z-score in a normally distributed dataset.**
#
# **Role**: Data Science, Data Analyst
# **Companies**: Amazon, Flipkart
# **Difficulty**: ⭐⭐⭐
#
# **Formula**:
#
# $$
# Z = \frac{X - \mu}{\sigma}
# $$
#
# Where:
#
# * $X$ = raw data point
# * $\mu$ = mean
# * $\sigma$ = standard deviation
#
# 🔹 A **positive Z-score** means the value is **above** the mean
# 🔹 A **negative Z-score** means it is **below** the mean
#
# ---
#
# ### **60. What is the critical value for a Z-test at a 95% confidence level?**
#
# **Role**: Data Science, Data Analyst
# **Companies**: Amazon, Flipkart
# **Difficulty**: ⭐⭐⭐
#
# **Answer**:
#
# * For a **two-tailed Z-test at 95% confidence**, the **critical Z-values** are:
#
#   $$
#   Z = \pm 1.96
#   $$
# * This means the central 95% of the distribution lies between -1.96 and +1.96.
#
# **📌Use in Hypothesis Testing**:
#
# * If $Z_{\text{calculated}} < -1.96$ or $Z_{\text{calculated}} > 1.96$, **reject** the null hypothesis.
#
# ---
#
# ### ✅ Python Example – One-Sample Z-Test
#
# ```python
# import numpy as np
# from scipy.stats import norm
#
# # Sample data
# sample_mean = 52
# population_mean = 50
# population_std = 4
# n = 30
#
# # Z-score
# z = (sample_mean - population_mean) / (population_std / np.sqrt(n))
#
# # p-value (two-tailed)
# p_value = 2 * (1 - norm.cdf(abs(z)))
#
# print(f"Z-score: {z:.2f}, P-value: {p_value:.4f}")
# ```
#
# ---

# %%
import numpy as np
from scipy.stats import norm

# Sample data
sample_mean = 52
population_mean = 50
population_std = 4
n = 30

# Z-score
z = (sample_mean - population_mean) / (population_std / np.sqrt(n))

# p-value (two-tailed)
p_value = 2 * (1 - norm.cdf(abs(z)))

print(f"Z-score: {z:.2f}, P-value: {p_value:.4f}")
# Out:
# Z-score: 2.74, P-value: 0.0062

# %% [markdown]
# Excellent! Let's dive into **🔹Topic 13: Hypothesis Testing and Mechanism**, which is crucial for decision-making in data science and analytics.
#
# ---
#
# ## 🔹Topic 13: Hypothesis Testing and Mechanism
#
# ---
#
# ### **61. What is hypothesis testing, and why is it important in statistics?**
#
# **Roles**: Data Science, Machine Learning Engineer
# **Companies**: Amazon, Flipkart
# **Difficulty**: ⭐⭐⭐
#
# **Answer**:
# **Hypothesis Testing** is a statistical method used to make inferences or draw conclusions about a population based on sample data.
#
# * **Null Hypothesis ($H_0$)**: Assumes no effect or no difference.
# * **Alternative Hypothesis ($H_1$)**: Assumes some effect or difference exists.
#
# ✅ It's important because it provides a **framework to test assumptions** and control the likelihood of making incorrect decisions using **probability theory**.
#
# ---
#
# ### **62. Explain the steps involved in performing a hypothesis test.**
#
# **Roles**: Data Science, Machine Learning Engineer
# **Companies**: Amazon, Flipkart
# **Difficulty**: ⭐⭐⭐
#
# **Steps**:
#
# 1. **Formulate Hypotheses**:
#
#    * $H_0$: No change/effect.
#    * $H_1$: There is a change/effect.
#
# 2. **Choose Significance Level ($\alpha$)**:
#
#    * Commonly: 0.05 (5%)
#
# 3. **Select the appropriate test**:
#
#    * Z-test, T-test, Chi-square, etc.
#
# 4. **Calculate the Test Statistic**:
#
#    * Based on the sample data.
#
# 5. **Determine the p-value**:
#
#    * Probability of obtaining the result under $H_0$.
#
# 6. **Compare p-value with $\alpha$**:
#
#    * If $p < \alpha$, reject $H_0$; otherwise, fail to reject it.
#
# ---
#
# ### **63. How do you formulate null and alternative hypotheses in a research scenario?**
#
# **Roles**: Data Science, Machine Learning Engineer
# **Companies**: Amazon, Flipkart
# **Difficulty**: ⭐⭐⭐
#
# **Example**: Suppose you're testing if a new website layout increases average session time.
#
# * $H_0$: The new layout does **not** increase average session time ($\mu_{\text{new}} \leq \mu_{\text{old}}$)
# * $H_1$: The new layout **increases** average session time ($\mu_{\text{new}} > \mu_{\text{old}}$)
#
# 👉 Always express hypotheses in terms of **parameters**, not sample statistics.
#
# ---
#
# ### **64. What is the significance of the p-value in hypothesis testing?**
#
# **Roles**: Business Analyst, Data Science
# **Companies**: Microsoft, Ola
# **Difficulty**: ⭐⭐⭐
#
# **Answer**:
# The **p-value** represents the probability of obtaining a result **as extreme or more extreme** than the observed one, assuming $H_0$ is true.
#
# * **Small p-value (< α)**: Strong evidence **against** $H_0$; reject it.
# * **Large p-value**: Weak evidence; **fail to reject** $H_0$.
#
# 📌 Helps quantify uncertainty rather than relying on binary "true/false" logic.
#
# ---
#
# ### **65. What is a Z-test, and how is it different from other types of hypothesis tests?**
#
# **Roles**: Data Science, Business Analyst
# **Companies**: Flipkart, Amazon
# **Difficulty**: ⭐⭐⭐
#
# **Z-Test** is used when:
#
# * Population standard deviation is **known**
# * Sample size is **large** (typically $n \geq 30$)
#
# **Compared to**:
#
# * **T-Test**: Used when population standard deviation is unknown.
# * **Chi-Square Test**: Used for categorical variables.
# * **ANOVA**: Compares means across **more than two groups**.
#
# ---
#
# ### **66. Explain how to perform a Z-test on a sample mean when population variance is known.**
#
# **Roles**: Data Analyst, Data Scientist
# **Companies**: Google, Paytm
# **Difficulty**: ⭐⭐
#
# **Steps**:
#
# 1. Compute Z-statistic:
#
#    $$
#    Z = \frac{\bar{x} - \mu}{\sigma / \sqrt{n}}
#    $$
# 2. Compare against critical Z-value (e.g., ±1.96 at 95% confidence).
# 3. Or compute p-value and compare with significance level.
#
# ---
#
# ### **67. When would you use a one-tailed Z-test vs. a two-tailed Z-test?**
#
# **Roles**: Data Science, Data Analyst
# **Companies**: Flipkart, Amazon
# **Difficulty**: ⭐⭐⭐
#
# | Test Type  | Use When…                                     | Example                      |
# | ---------- | --------------------------------------------- | ---------------------------- |
# | One-Tailed | You're testing for **directional** change     | New ad increases sales       |
# | Two-Tailed | You're testing for **any** significant change | Drug effect is **different** |
#
# ---
#
# ### **68. How do you implement a Z-test in Python using `scipy.stats`?**
#
# **Roles**: Data Science, Data Analyst
# **Companies**: Flipkart, Amazon
# **Difficulty**: ⭐⭐⭐
#
# ```python
# from scipy.stats import norm
# import numpy as np
#
# # Sample details
# sample_mean = 53
# population_mean = 50
# population_std = 5
# n = 40
#
# # Z-score
# z = (sample_mean - population_mean) / (population_std / np.sqrt(n))
#
# # p-value (two-tailed)
# p_value = 2 * (1 - norm.cdf(abs(z)))
#
# print(f"Z-score: {z:.2f}, P-value: {p_value:.4f}")
# ```
#
# ---

# %%
from scipy.stats import norm
import numpy as np

# Sample details
sample_mean = 53
population_mean = 50
population_std = 5
n = 40

# Z-score
z = (sample_mean - population_mean) / (population_std / np.sqrt(n))

# p-value (two-tailed)
p_value = 2 * (1 - norm.cdf(abs(z)))

print(f"Z-score: {z:.2f}, P-value: {p_value:.4f}")
# Out:
# Z-score: 3.79, P-value: 0.0001

# %% [markdown]
# Great! Let's now cover the final section: **🔹Topic 14: Type I and Type II Errors**, which is essential for evaluating the risks in hypothesis testing.
#
# ---
#
# ## 🔹Topic 14: Type I and Type II Errors
#
# ---
#
# ### **69. What is the difference between Type I and Type II errors in hypothesis testing?**
#
# **Roles**: Data Analyst, Data Scientist
# **Companies**: Flipkart, Swiggy
# **Difficulty**: ⭐⭐
#
# | Error Type        | Definition                                | Symbol | Example                                              |
# | ----------------- | ----------------------------------------- | ------ | ---------------------------------------------------- |
# | **Type I Error**  | Rejecting a true null hypothesis          | **α**  | Saying a medicine works when it actually doesn’t     |
# | **Type II Error** | Failing to reject a false null hypothesis | **β**  | Saying a medicine doesn't work when it actually does |
#
# 📌 In simple terms:
#
# * **Type I** = **False Positive**
# * **Type II** = **False Negative**
#
# ---
#
# ### **70. Explain the significance of the significance level (alpha) in relation to Type I errors.**
#
# **Roles**: Data Analyst, Data Scientist
# **Companies**: Flipkart, Swiggy
# **Difficulty**: ⭐⭐
#
# **Answer**:
#
# * The **significance level (α)** is the threshold probability for making a **Type I error**.
# * Common values: 0.05 or 0.01 (5% or 1%)
# * If $\alpha = 0.05$, you accept a **5% chance** of wrongly rejecting the null hypothesis.
#
# 🎯 Lower α → Lower risk of Type I error, but → Higher risk of Type II error.
#
# ---
#
# ### **71. How do Type II errors relate to statistical power in hypothesis tests?**
#
# **Roles**: Data Science, Machine Learning Engineer
# **Companies**: Microsoft, Ola
# **Difficulty**: ⭐⭐⭐
#
# **Answer**:
#
# * **Power of a test** = $1 - \beta$ = Probability of correctly rejecting a false null hypothesis.
# * A **low Type II error (β)** means **high power**, indicating the test is more sensitive to detecting real effects.
#
# ✅ **High power** is desirable → You’re more likely to detect a true difference or effect.
#
# **Ways to increase power**:
#
# * Increase sample size
# * Increase effect size
# * Use more sensitive statistical tests
# * Accept a slightly higher α
#
# ---
#
# ### **72. How can you minimize the occurrence of Type I and Type II errors?**
#
# **Roles**: Data Science, Machine Learning Engineer
# **Companies**: Microsoft, Ola
# **Difficulty**: ⭐⭐⭐
#
# **Answer**:
# To balance and minimize both errors:
#
# * Choose an appropriate **α** (e.g., 0.05)
# * **Increase sample size** to reduce variance and improve test sensitivity
# * **Use appropriate statistical tests** tailored to your data
# * **Predefine effect size** and run power analysis before testing
#
# 📊 Example:
#
# ```python
# from statsmodels.stats.power import TTestIndPower
#
# analysis = TTestIndPower()
# power = analysis.solve_power(effect_size=0.5, nobs1=100, alpha=0.05, power=None)
# print(f"Power of the test: {power:.2f}")
# ```
#
# ---

# %%
from statsmodels.stats.power import TTestIndPower

analysis = TTestIndPower()
power = analysis.solve_power(effect_size=0.5, nobs1=100, alpha=0.05, power=None)
print(f"Power of the test: {power:.2f}")
# Out:
# Power of the test: 0.94

# %% [markdown]
# ### 1. **What is a T-test, and when should it be used instead of a Z-test?**
#
# A **T-test** is a statistical test used to compare the mean of a sample to a known value (one-sample), or to compare the means of two samples (two-sample). It's used when:
#
# * The sample size is **small** (typically n < 30).
# * The **population standard deviation is unknown**.
# * The data is **approximately normally distributed**.
#
# Use a **Z-test** when the population variance is known and the sample size is large.
#
# ---
#
# ### 2. **Explain how a paired T-test differs from an independent T-test.**
#
# * **Independent T-test** compares means from **two different groups** (e.g., male vs female test scores).
# * **Paired T-test** compares means from the **same group at two time points** (e.g., before and after training).
#
# ---
#
# ### 3. **What assumptions need to be met for a valid T-test?**
#
# * The data should be **normally distributed**.
# * Data should be **continuous** and **measured at interval/ratio level**.
# * For independent T-tests, the variances should be **equal** (homogeneity of variance).
# * The samples should be **random and independent**.
#
# ---
#
# ### 4. **How would you implement a T-test in Python using scipy.stats?**
#
# #### Example (Independent T-Test):
#
# ```python
# from scipy import stats
#
# group1 = [23, 21, 18, 25, 22]
# group2 = [30, 28, 26, 31, 29]
#
# t_stat, p_val = stats.ttest_ind(group1, group2)
#
# print("T-statistic:", t_stat)
# print("P-value:", p_val)
# ```
#
# #### Example (Paired T-Test):
#
# ```python
# before = [65, 70, 75, 80, 85]
# after = [68, 74, 78, 82, 88]
#
# t_stat, p_val = stats.ttest_rel(before, after)
#
# print("T-statistic:", t_stat)
# print("P-value:", p_val)
# ```
#
# ---
#
# ### 5. **What is Student's T-distribution, and how does it differ from the standard normal distribution?**
#
# * The **Student’s T-distribution** is a family of curves used when the **sample size is small** and **population variance is unknown**.
# * It has **fatter tails** than the normal distribution.
# * As the **degrees of freedom increase**, it approaches the **normal distribution**.
#
# ---

# %%
before = [65, 70, 75, 80, 85]
after = [68, 74, 78, 82, 88]

t_stat, p_val = stats.ttest_rel(before, after)

print("T-statistic:", t_stat)
print("P-value:", p_val)
# Out:
# T-statistic: -9.486832980505138
# P-value: 0.0006889093649396111

# %%
from scipy import stats

group1 = [23, 21, 18, 25, 22]
group2 = [30, 28, 26, 31, 29]

t_stat, p_val = stats.ttest_ind(group1, group2)

print("T-statistic:", t_stat)
print("P-value:", p_val)
# Out:
# T-statistic: -4.853626716970755
# P-value: 0.0012660072042684149

# %% [markdown]
# Great! Let’s continue with questions **6 to 12** on **Student’s T-distribution and comparison with Z-test**:
#
# ---
#
# ### 6. **When would you use Student's T-distribution over the normal distribution?**
#
# You should use **Student’s T-distribution** when:
#
# * The **sample size is small** (typically n < 30).
# * The **population standard deviation is unknown**.
# * The data is **approximately normally distributed**.
#
# As the sample size increases, the T-distribution becomes similar to the normal distribution.
#
# ---
#
# ### 7. **What are the properties of Student's T-distribution?**
#
# * It is **bell-shaped and symmetric**, like the normal distribution.
# * It has **heavier tails**, allowing for more variability.
# * It depends on the **degrees of freedom (df)**.
# * As df increases, the T-distribution **approaches the normal distribution**.
# * The **mean = 0**, and **variance > 1** (exact variance = df / (df - 2) for df > 2).
#
# ---
#
# ### 8. **How do you calculate the degrees of freedom in a T-test using Student’s T-distribution?**
#
# The degrees of freedom (df) depend on the type of T-test:
#
# * **One-sample T-test**:
#
#   $$
#   df = n - 1
#   $$
#
# * **Independent two-sample T-test (equal variances)**:
#
#   $$
#   df = n_1 + n_2 - 2
#   $$
#
# * **Paired T-test**:
#
#   $$
#   df = n - 1
#   $$
#
# * **Unequal variances (Welch's T-test)**:
#
#   $$
#   df = \frac{ \left( \frac{s_1^2}{n_1} + \frac{s_2^2}{n_2} \right)^2 }{ \frac{ \left( \frac{s_1^2}{n_1} \right)^2 }{n_1 - 1} + \frac{ \left( \frac{s_2^2}{n_2} \right)^2 }{n_2 - 1} }
#   $$
#
# ---
#
# ### 9. **What are the key differences between a T-test and a Z-test?**
#
# | Feature            | T-test                | Z-test                            |
# | ------------------ | --------------------- | --------------------------------- |
# | Use case           | Small sample (n < 30) | Large sample (n ≥ 30)             |
# | Population std dev | Unknown               | Known                             |
# | Distribution used  | T-distribution        | Standard normal (Z) distribution  |
# | Tail heaviness     | Heavier tails         | Lighter tails                     |
# | Common in          | Real-world scenarios  | Theoretical/large data situations |
#
# ---
#
# ### 10. **When would you choose to use a T-test over a Z-test in a research scenario?**
#
# Use a **T-test** when:
#
# * Sample size is **small (<30)**.
# * You **do not know the population standard deviation**.
# * You are working with **real-world data** where the population parameters are not available.
#
# Use a **Z-test** when:
#
# * Sample size is **large (≥30)**.
# * You **know the population standard deviation**.
#
# ---
#
# ### 11. **Explain how sample size impacts the decision to use a T-test or Z-test.**
#
# * **Smaller samples** → Use **T-test** due to greater uncertainty.
# * As the **sample size increases**, the **T-distribution approaches normality**, and the **Z-test becomes more appropriate**.
# * **Large samples reduce standard error**, making the Z-test more reliable even without knowing the population standard deviation.
#
# ---
#
# ### 12. **How does the assumption of population variance affect the choice between T-test and Z-test?**
#
# * **Known variance** → Use **Z-test**.
# * **Unknown variance** → Use **T-test** (estimate variance from sample).
#
# Knowing the **population variance** eliminates the need for estimating uncertainty, which is why the **Z-test** is stricter and rarely used in real-world problems where population variance is unknown.
#
# ---
#
# Perfect! Let's now continue with **Questions 13 to 16** under the **"Confidence Interval and Margin of Error"** section:
#
# ---
#
# ### 13. **What is a confidence interval, and why is it important in inferential statistics?**
#
# A **confidence interval (CI)** is a range of values derived from sample data that is likely to contain the **true population parameter** (like the mean or proportion) with a certain level of confidence.
#
# For example, a 95% CI means we are 95% confident the true parameter lies within this range.
#
# **Importance:**
#
# * Helps **quantify uncertainty** in estimates.
# * Gives a **range** rather than a single point estimate.
# * Critical in **decision-making** and **hypothesis testing**.
#
# ---
#
# ### 14. **Explain the relationship between confidence intervals and the margin of error.**
#
# The **confidence interval** is computed as:
#
# $$
# \text{CI} = \text{point estimate} \pm \text{margin of error}
# $$
#
# * **Margin of Error (ME)** is the amount added/subtracted from the estimate to create the range.
# * ME depends on:
#
#   * **Confidence level** (e.g., 95%)
#   * **Sample size** (larger size → smaller ME)
#   * **Standard deviation** or **standard error**
#
# **Higher confidence** ⇒ **larger margin of error**, and **vice versa**.
#
# ---
#
# ### 15. **How do you interpret a 95% confidence interval in statistical analysis?**
#
# If we compute a 95% CI for the population mean as **\[45, 55]**, we interpret it as:
#
# > "We are 95% confident that the true population mean lies between 45 and 55."
#
# It **does not mean** there's a 95% chance that the true value is in the interval for this particular case. Instead, it means that if we repeated the sampling process many times, **95% of the computed intervals would contain the true mean**.
#
# ---
#
# ### 16. **How can you calculate confidence intervals in Python using `scipy.stats`?**
#
# Here’s a simple Python example using `scipy.stats` for a **95% confidence interval of the mean**:
#
# ```python
# import numpy as np
# import scipy.stats as stats
#
# # Sample data
# data = [12, 15, 14, 10, 13, 17, 16]
# n = len(data)
# mean = np.mean(data)
# std_err = stats.sem(data)  # Standard error of the mean
#
# # 95% confidence interval
# confidence = 0.95
# h = std_err * stats.t.ppf((1 + confidence) / 2, df=n-1)
# lower_bound = mean - h
# upper_bound = mean + h
#
# print(f"95% Confidence Interval: ({lower_bound:.2f}, {upper_bound:.2f})")
# ```
#
# 📌 Note: If population standard deviation is known and the sample size is large, you can use the **Z-distribution** instead.
#
# ---

# %%
import numpy as np
import scipy.stats as stats

# Sample data
data = [12, 15, 14, 10, 13, 17, 16]
n = len(data)
mean = np.mean(data)
std_err = stats.sem(data)  # Standard error of the mean

# 95% confidence interval
confidence = 0.95
h = std_err * stats.t.ppf((1 + confidence) / 2, df=n-1)
lower_bound = mean - h
upper_bound = mean + h

print(f"95% Confidence Interval: ({lower_bound:.2f}, {upper_bound:.2f})")
# Out:
# 95% Confidence Interval: (11.63, 16.09)

# %% [markdown]
# Great! Let's move on to **Questions 17 to 20** under the **Chi-Square Test & Chi-Square Distribution** section:
#
# ---
#
# ### 17. **What is the Chi-square test, and when is it used in statistical analysis?**
#
# The **Chi-square test** is a **non-parametric test** used to examine the relationship between **categorical variables** or assess how well observed data fits expected data.
#
# There are two main types:
#
# * **Chi-square test of independence**: Checks if two categorical variables are independent.
# * **Chi-square goodness-of-fit test**: Checks if sample data matches a theoretical distribution.
#
# **Use case example**: Testing if gender is independent of product preference in a survey.
#
# ---
#
# ### 18. **Explain how to perform a Chi-square test of independence.**
#
# Steps:
#
# 1. **Create a contingency table** (e.g., rows = gender, columns = product preference).
# 2. **Compute expected frequencies** assuming independence.
# 3. **Use the formula**:
#
# $$
# \chi^2 = \sum \frac{(O_i - E_i)^2}{E_i}
# $$
#
# Where $O_i$ = observed frequency, $E_i$ = expected frequency.
#
# 4. Compare the test statistic to the **Chi-square distribution** with appropriate **degrees of freedom (df)**:
#
# $$
# df = (rows - 1) \times (columns - 1)
# $$
#
# 5. Make a decision based on the **p-value** and your significance level (e.g., 0.05).
#
# ---
#
# ### 19. **How is the Chi-square distribution related to categorical data analysis?**
#
# * The **Chi-square distribution** is used as the reference distribution for the Chi-square test.
# * It applies when testing **frequencies** or **proportions** in **categorical data**.
# * It is **right-skewed** and **non-negative**.
# * As the **degrees of freedom increase**, the distribution becomes more symmetric.
#
# ---
#
# ### 20. **Provide a Python implementation of a Chi-square test using `scipy.stats`.**
#
# Let’s do a test of independence between gender and product preference:
#
# ```python
# import numpy as np
# import scipy.stats as stats
#
# # Contingency table (2x3): rows = Gender (Male, Female), columns = Product A/B/C
# observed = np.array([[30, 20, 25], [25, 30, 20]])
#
# # Perform Chi-square test of independence
# chi2, p, dof, expected = stats.chi2_contingency(observed)
#
# print(f"Chi2 Statistic: {chi2:.2f}")
# print(f"P-value: {p:.4f}")
# print(f"Degrees of Freedom: {dof}")
# print("Expected Frequencies:\n", expected)
# ```
#
# 🧠 If **p-value < 0.05**, we reject the null hypothesis and conclude that **gender and product preference are not independent**.
#
# ---

# %%
import numpy as np
import scipy.stats as stats

# Contingency table (2x3): rows = Gender (Male, Female), columns = Product A/B/C
observed = np.array([[30, 20, 25], [25, 30, 20]])

# Perform Chi-square test of independence
chi2, p, dof, expected = stats.chi2_contingency(observed)

print(f"Chi2 Statistic: {chi2:.2f}")
print(f"P-value: {p:.4f}")
print(f"Degrees of Freedom: {dof}")
print("Expected Frequencies:\n", expected)
# Out:
# Chi2 Statistic: 3.01
# P-value: 0.2220
# Degrees of Freedom: 2
# Expected Frequencies:
#  [[27.5 25.  22.5]
#  [27.5 25.  22.5]]

# %% [markdown]
# Excellent! Let’s move on to **Questions 21 to 24** under the **Bayes’ Theorem** section:
#
# ---
#
# ### 21. **What is Bayes’ theorem, and how is it applied in data science?**
#
# **Bayes’ theorem** describes the probability of an event, based on prior knowledge of conditions that might be related to the event. It is a fundamental tool in **probabilistic reasoning** and **machine learning**.
#
# **Formula:**
#
# $$
# P(A|B) = \frac{P(B|A) \cdot P(A)}{P(B)}
# $$
#
# Where:
#
# * $P(A|B)$: Posterior probability
# * $P(B|A)$: Likelihood
# * $P(A)$: Prior probability
# * $P(B)$: Marginal probability
#
# **Applications in data science:**
#
# * **Spam filtering** (e.g., Naive Bayes)
# * **Medical diagnosis**
# * **Predictive modeling**
# * **Recommendation systems**
#
# ---
#
# ### 22. **Explain how Bayes’ theorem is used in spam filtering or medical diagnostics.**
#
# #### In **spam filtering**:
#
# Bayes' theorem helps determine the probability that an email is spam given certain words.
#
# Example:
# Let **A** = Email is spam, **B** = Email contains the word "win".
# Bayes' helps compute $P(\text{spam}|\text{"win"})$ based on past emails.
#
# #### In **medical diagnostics**:
#
# Used to update the probability of having a disease given a positive test result.
#
# Example:
# Let **A** = Has disease, **B** = Tests positive.
# Bayes' calculates the chance of disease **after** a positive test, considering false positives and prevalence.
#
# ---
#
# ### 23. **What is the difference between prior, likelihood, and posterior probabilities in Bayes’ theorem?**
#
# | Term           | Meaning                                                                                 |
# | -------------- | --------------------------------------------------------------------------------------- |
# | **Prior**      | Initial belief before observing the evidence (e.g., disease prevalence).                |
# | **Likelihood** | Probability of observing the data given the hypothesis (e.g., test result if diseased). |
# | **Posterior**  | Updated belief after seeing the evidence.                                               |
#
# **Bayes' theorem** combines **prior** and **likelihood** to calculate the **posterior**.
#
# ---
#
# ### 24. **How would you implement Bayes’ theorem in Python for a classification problem?**
#
# Here’s an example of **Naive Bayes** implementation using `sklearn`:
#
# ```python
# from sklearn.naive_bayes import MultinomialNB
# from sklearn.feature_extraction.text import CountVectorizer
#
# # Sample training data
# X_train = ["buy cheap now", "limited offer", "click here", "hello friend", "meeting agenda", "project update"]
# y_train = ["spam", "spam", "spam", "ham", "ham", "ham"]
#
# # Vectorize text data
# vectorizer = CountVectorizer()
# X_train_counts = vectorizer.fit_transform(X_train)
#
# # Train Naive Bayes model
# model = MultinomialNB()
# model.fit(X_train_counts, y_train)
#
# # Predict new email
# X_test = vectorizer.transform(["cheap offer for you"])
# prediction = model.predict(X_test)
#
# print("Prediction:", prediction[0])
# ```
#
# This shows how **Bayesian classification** can be implemented using text data.
#
# ---

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import CountVectorizer

# Sample training data
X_train = ["buy cheap now", "limited offer", "click here", "hello friend", "meeting agenda", "project update"]
y_train = ["spam", "spam", "spam", "ham", "ham", "ham"]

# Vectorize text data
vectorizer = CountVectorizer()
X_train_counts = vectorizer.fit_transform(X_train)

# Train Naive Bayes model
model = MultinomialNB()
model.fit(X_train_counts, y_train)

# Predict new email
X_test = vectorizer.transform(["cheap offer for you"])
prediction = model.predict(X_test)

print("Prediction:", prediction[0])
# Out:
# Prediction: spam

# %% [markdown]
# Great! Let's proceed to **Questions 25 to 28** under the **Goodness of Fit Test** section:
#
# ---
#
# ### 25. **What is the goodness-of-fit test, and how is it used in statistical analysis?**
#
# The **Goodness-of-Fit Test** checks whether the sample data matches a population with a specific distribution. It is most commonly implemented using the **Chi-square Goodness-of-Fit Test**.
#
# **Purpose:**
# To determine if observed categorical frequencies differ significantly from expected frequencies under a hypothesized distribution.
#
# **Example use cases:**
#
# * Testing whether a die is fair.
# * Checking if survey responses match expected proportions.
#
# ---
#
# ### 26. **How is the Chi-square goodness-of-fit test performed?**
#
# **Steps:**
#
# 1. Define the null hypothesis $H_0$: The observed distribution fits the expected distribution.
# 2. Calculate expected frequencies based on the assumed distribution.
# 3. Compute the test statistic:
#
# $$
# \chi^2 = \sum \frac{(O_i - E_i)^2}{E_i}
# $$
#
# Where:
#
# * $O_i$: Observed frequency
# * $E_i$: Expected frequency
#
# 4. Compare the $\chi^2$ value with the critical value from the Chi-square distribution table.
# 5. Reject or fail to reject $H_0$.
#
# ---
#
# ### 27. **When would you use a goodness-of-fit test for a dataset?**
#
# You use it when:
#
# * You're validating if a sample follows a known theoretical distribution (e.g., uniform, binomial, Poisson).
# * You want to test whether the observed categorical data conform to expected proportions.
# * You're analyzing surveys, dice rolls, genetics, or customer behavior patterns.
#
# ---
#
# ### 28. **How can you implement a goodness-of-fit test in Python using `scipy.stats`?**
#
# Here’s a simple Python example for testing whether a die is fair:
#
# ```python
# import scipy.stats as stats
#
# # Observed frequencies from rolling a die 60 times
# observed = [8, 9, 10, 11, 12, 10]
#
# # Expected frequencies if the die is fair
# expected = [10] * 6
#
# # Perform Chi-square goodness-of-fit test
# chi2_stat, p_value = stats.chisquare(f_obs=observed, f_exp=expected)
#
# print("Chi-square statistic:", chi2_stat)
# print("P-value:", p_value)
# ```
#
# **Interpretation:**
#
# * If `p-value < 0.05`, reject the null hypothesis — the die is not fair.
# * If `p-value >= 0.05`, fail to reject — no evidence against fairness.
#
# ---

# %%
import scipy.stats as stats

# Observed frequencies from rolling a die 60 times
observed = [8, 9, 10, 11, 12, 10]

# Expected frequencies if the die is fair
expected = [10] * 6

# Perform Chi-square goodness-of-fit test
chi2_stat, p_value = stats.chisquare(f_obs=observed, f_exp=expected)

print("Chi-square statistic:", chi2_stat)
print("P-value:", p_value)
# Out:
# Chi-square statistic: 1.0
# P-value: 0.9625657732472964

# %% [markdown]
# Excellent! Here's the detailed explanation for **Questions 29 to 36** under the **F-Distribution and F-Test** section:
#
# ---
#
# ### 29. **What is the F-distribution, and how is it used in statistical analysis?**
#
# The **F-distribution** is a continuous probability distribution that arises frequently in ANOVA and regression analysis when comparing **two variances**.
#
# **Key uses:**
#
# * Comparing **variances** between two populations.
# * Testing the **overall significance** in multiple regression.
# * Performing **ANOVA (Analysis of Variance)**.
#
# It is **right-skewed** and depends on two degrees of freedom: $df_1$ (numerator) and $df_2$ (denominator).
#
# ---
#
# ### 30. **Explain the relationship between the F-distribution and analysis of variance (ANOVA).**
#
# In **ANOVA**, the F-distribution is used to compare **between-group variance** to **within-group variance**:
#
# $$
# F = \frac{\text{Variance Between Groups}}{\text{Variance Within Groups}}
# $$
#
# * If the group means are equal (null hypothesis), this ratio should be close to 1.
# * A **larger F-value** implies that the group means are different, indicating a statistically significant result.
#
# ---
#
# ### 31. **What are the properties of the F-distribution in hypothesis testing?**
#
# * **Non-negative**: F-values are always ≥ 0.
# * **Right-skewed**: Tail extends to the right.
# * Depends on **two degrees of freedom**.
# * **Mean > 1** for small degrees of freedom.
# * Used for **variance comparison** and **ANOVA**.
#
# ---
#
# ### 32. **How do you calculate the F-statistic in Python using `scipy.stats`?**
#
# Example: Compare variances of two datasets
#
# ```python
# import scipy.stats as stats
# import numpy as np
#
# # Sample data
# group1 = [12, 14, 15, 16, 17]
# group2 = [22, 25, 26, 23, 24]
#
# # Calculate variances
# var1 = np.var(group1, ddof=1)
# var2 = np.var(group2, ddof=1)
#
# # Compute F-statistic
# f_stat = var1 / var2
# dof1 = len(group1) - 1
# dof2 = len(group2) - 1
#
# # Compute p-value
# p_value = 1 - stats.f.cdf(f_stat, dfn=dof1, dfd=dof2)
#
# print("F-statistic:", f_stat)
# print("P-value:", p_value)
# ```
#
# ---
#
# ### 33. **What is an F-test, and how does it differ from other statistical tests?**
#
# An **F-test** is used to:
#
# * Compare **two variances** (variance ratio test).
# * Determine **overall model significance** in regression.
# * Perform **ANOVA** to check if multiple groups have the same mean.
#
# **Difference from other tests:**
#
# * Unlike the **T-test** (used for means), the **F-test** compares **variances**.
# * Used when **more than two groups** or multiple variables are involved.
#
# ---
#
# ### 34. **Explain how an F-test is used in testing for the equality of variances.**
#
# **F-test for Variance:**
#
# * $H_0$: Variances of two populations are equal.
# * Calculate F-statistic:
#
# $$
# F = \frac{s_1^2}{s_2^2} \quad \text{(where } s_1^2 > s_2^2 \text{)}
# $$
#
# * Compare with the critical F-value from F-distribution.
# * If the **p-value < α**, reject $H_0$: variances are significantly different.
#
# ---
#
# ### 35. **What assumptions must be met to perform an F-test?**
#
# 1. **Independence** of observations.
# 2. **Normally distributed** populations.
# 3. **Random sampling** from populations.
# 4. The variables must be **continuous**.
#
# ---
#
# ### 36. **How do you perform an F-test in Python using `scipy.stats`?**
#
# ```python
# import scipy.stats as stats
# import numpy as np
#
# # Two samples
# sample1 = [10, 12, 9, 11, 13]
# sample2 = [20, 21, 19, 22, 20]
#
# # Sample variances
# var1 = np.var(sample1, ddof=1)
# var2 = np.var(sample2, ddof=1)
#
# # F-statistic (larger variance on top)
# f_stat = var1 / var2 if var1 > var2 else var2 / var1
#
# # Degrees of freedom
# dof1 = len(sample1) - 1
# dof2 = len(sample2) - 1
#
# # P-value (right-tail test)
# p_value = 1 - stats.f.cdf(f_stat, dfn=dof1, dfd=dof2)
#
# print("F-statistic:", f_stat)
# print("P-value:", p_value)
# ```
#
# ---

# %%
import scipy.stats as stats
import numpy as np

# Two samples
sample1 = [10, 12, 9, 11, 13]
sample2 = [20, 21, 19, 22, 20]

# Sample variances
var1 = np.var(sample1, ddof=1)
var2 = np.var(sample2, ddof=1)

# F-statistic (larger variance on top)
f_stat = var1 / var2 if var1 > var2 else var2 / var1

# Degrees of freedom
dof1 = len(sample1) - 1
dof2 = len(sample2) - 1

# P-value (right-tail test)
p_value = 1 - stats.f.cdf(f_stat, dfn=dof1, dfd=dof2)

print("F-statistic:", f_stat)
print("P-value:", p_value)
# Out:
# F-statistic: 1.923076923076923
# P-value: 0.27103076250182256

# %%
import scipy.stats as stats
import numpy as np

# Sample data
group1 = [12, 14, 15, 16, 17]
group2 = [22, 25, 26, 23, 24]

# Calculate variances
var1 = np.var(group1, ddof=1)
var2 = np.var(group2, ddof=1)

# Compute F-statistic
f_stat = var1 / var2
dof1 = len(group1) - 1
dof2 = len(group2) - 1

# Compute p-value
p_value = 1 - stats.f.cdf(f_stat, dfn=dof1, dfd=dof2)

print("F-statistic:", f_stat)
print("P-value:", p_value)
# Out:
# F-statistic: 1.48
# P-value: 0.35665133765231105

# %% [markdown]
# Great! Here's the detailed explanation for **Questions 37 to 42** under the **ANOVA and Its Assumptions** section:
#
# ---
#
# ### 37. **What is ANOVA, and why is it used in statistical analysis?**
#
# **ANOVA (Analysis of Variance)** is a statistical method used to test whether there are any statistically significant differences between the **means of three or more independent groups**.
#
# * It uses the **F-distribution** to compare the ratio of between-group variance to within-group variance.
# * If this ratio is significantly large, it suggests that at least one group mean is different.
#
# **Use case:** When comparing the effectiveness of 3+ marketing strategies, drugs, teaching methods, etc.
#
# ---
#
# ### 38. **Explain the assumptions that need to be met before conducting an ANOVA test.**
#
# 1. **Independence**: Observations are independent across and within groups.
# 2. **Normality**: Each group is approximately normally distributed.
# 3. **Homogeneity of variances (homoscedasticity)**: Variances across the groups are equal.
#
# Failing to meet these assumptions can lead to misleading conclusions. For unequal variances, alternatives like **Welch's ANOVA** may be used.
#
# ---
#
# ### 39. **How does one-way ANOVA differ from two-way ANOVA?**
#
# | Feature         | One-Way ANOVA                        | Two-Way ANOVA                                |
# | --------------- | ------------------------------------ | -------------------------------------------- |
# | **Factors**     | One independent variable (factor)    | Two independent variables (factors)          |
# | **Interaction** | No interaction considered            | Can test interaction effects between factors |
# | **Use case**    | Comparing test scores across schools | Comparing scores across schools and genders  |
#
# **One-way ANOVA** answers: *Does the group mean differ across categories of one factor?*
# **Two-way ANOVA** answers: *How do two factors affect a dependent variable, and do they interact?*
#
# ---
#
# ### 40. **Provide a Python implementation of ANOVA using `statsmodels` or `scipy.stats`.**
#
# **Using `scipy.stats.f_oneway()` (One-way ANOVA):**
#
# ```python
# from scipy.stats import f_oneway
#
# # Sample data: 3 groups
# group1 = [23, 21, 22, 24, 20]
# group2 = [30, 31, 29, 28, 32]
# group3 = [40, 39, 41, 42, 38]
#
# # Perform ANOVA
# f_stat, p_value = f_oneway(group1, group2, group3)
#
# print("F-statistic:", f_stat)
# print("P-value:", p_value)
# ```
#
# **Using `statsmodels`:**
#
# ```python
# import pandas as pd
# import statsmodels.api as sm
# from statsmodels.formula.api import ols
#
# # Data
# data = {
#     'score': [23, 21, 22, 24, 20, 30, 31, 29, 28, 32, 40, 39, 41, 42, 38],
#     'group': ['A']*5 + ['B']*5 + ['C']*5
# }
#
# df = pd.DataFrame(data)
#
# # One-way ANOVA
# model = ols('score ~ group', data=df).fit()
# anova_result = sm.stats.anova_lm(model, typ=2)
#
# print(anova_result)
# ```
#
# ---
#
# ### 41. **What are the different types of ANOVA, and when should each be used?**
#
# 1. **One-Way ANOVA**: One factor with 3+ groups (e.g., 3 brands).
# 2. **Two-Way ANOVA**: Two factors (e.g., brand and gender).
# 3. **Repeated Measures ANOVA**: Same subjects measured multiple times (e.g., before and after treatment).
# 4. **MANOVA (Multivariate ANOVA)**: Multiple dependent variables.
#
# **Use case decision:**
#
# * Use **one-way** when testing one categorical feature.
# * Use **two-way** when two categorical features might influence the outcome.
# * Use **repeated measures** when using the **same subjects over time**.
#
# ---
#
# ### 42. **Explain the difference between one-way ANOVA and two-way ANOVA.**
#
# | Aspect                    | One-Way ANOVA                          | Two-Way ANOVA                                              |
# | ------------------------- | -------------------------------------- | ---------------------------------------------------------- |
# | **Independent variables** | 1 categorical variable (factor)        | 2 categorical variables (factors)                          |
# | **Interaction**           | Not considered                         | Can examine interaction between two factors                |
# | **Use case**              | Comparing test scores across 3 schools | Comparing test scores by school **and** gender             |
# | **Complexity**            | Simpler                                | More complex, interprets both main and interaction effects |
#
# ---

# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols

# Data
data = {
    'score': [23, 21, 22, 24, 20, 30, 31, 29, 28, 32, 40, 39, 41, 42, 38],
    'group': ['A']*5 + ['B']*5 + ['C']*5
}

df = pd.DataFrame(data)

# One-way ANOVA
model = ols('score ~ group', data=df).fit()
anova_result = sm.stats.anova_lm(model, typ=2)

print(anova_result)
# Out:
#               sum_sq    df           F        PR(>F)
# group     813.333333   2.0  162.666667  2.026432e-09
# Residual   30.000000  12.0         NaN           NaN

# %%
from scipy.stats import f_oneway

# Sample data: 3 groups
group1 = [23, 21, 22, 24, 20]
group2 = [30, 31, 29, 28, 32]
group3 = [40, 39, 41, 42, 38]

# Perform ANOVA
f_stat, p_value = f_oneway(group1, group2, group3)

print("F-statistic:", f_stat)
print("P-value:", p_value)
# Out:
# F-statistic: 162.66666666666666
# P-value: 2.0264315085222992e-09
